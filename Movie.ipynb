# %%
import requests

# %%
#Isprobavanje dobijanja informacija o jednom filmu

api_key = '8f0d9811'
title = 'Focus'
year = '2015'
movieInfo = requests.get('http://www.omdbapi.com/?apikey='+api_key+'&t='+title+'&y='+year).json()
movieInfo
# Out:
# {'Title': 'Focus',
#  'Year': '2015',
#  'Rated': 'R',
#  'Released': '27 Feb 2015',
#  'Runtime': '105 min',
#  'Genre': 'Comedy, Crime, Drama',
#  'Director': 'Glenn Ficarra, John Requa',
#  'Writer': 'Glenn Ficarra, John Requa',
#  'Actors': 'Will Smith, Margot Robbie, Rodrigo Santoro',
#  'Plot': "In the midst of veteran con man Nicky's latest scheme, a woman from his past - now an accomplished femme fatale - shows up and throws his plans for a loop.",
#  'Language': 'English, Spanish',
#  'Country': 'United States, Argentina',
#  'Awards': '3 nominations',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTUwODg2OTA4OF5BMl5BanBnXkFtZTgwOTE5MTE4MzE@._V1_SX300.jpg',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.6/10'},
#   {'Source': 'Metacritic', 'Value': '56/100'}],
#  'Metascore': '56',
#  'imdbRating': '6.6',
#  'imdbVotes': '248,555',
#  'imdbID': 'tt2381941',
#  'Type': 'movie',
#  'DVD': '23 Mar 2017',
#  'BoxOffice': '$53,862,963',
#  'Production': 'N/A',
#  'Website': 'N/A',
#  'Response': 'True'}

# %%
#Ucitavanje imena filmova dok se ne prosledi niska "end"
titles = []

print("Input movie titles or end")
while True:
    line = input()
    if (line == 'end'):
        break;
    titles.append(line)
# Out:
# Input movie titles or end
# Avatar
# Focus
# Inside Out
# Minions
# Dictator
# Deadpool
# Arrival
# The Nice Guys
# end

# %%
#Dohvatanje informacija o unetim filmovima
movies = []
for title in titles:
    info =  requests.get('http://www.omdbapi.com/?apikey='+api_key+'&t='+title).json()
    movies.append(info)

# %%
#Ispisivanje filmova
for movie in movies:
    print(movie)
# Out:
# {'Title': 'Avatar', 'Year': '2009', 'Rated': 'PG-13', 'Released': '18 Dec 2009', 'Runtime': '162 min', 'Genre': 'Action, Adventure, Fantasy', 'Director': 'James Cameron', 'Writer': 'James Cameron', 'Actors': 'Sam Worthington, Zoe Saldana, Sigourney Weaver', 'Plot': 'A paraplegic Marine dispatched to the moon Pandora on a unique mission becomes torn between following his orders and protecting the world he feels is his home.', 'Language': 'English, Spanish', 'Country': 'United States', 'Awards': 'Won 3 Oscars. 89 wins & 131 nominations total', 'Poster': 'https://m.media-amazon.com/images/M/MV5BNjA3NGExZDktNDlhZC00NjYyLTgwNmUtZWUzMDYwMTZjZWUyXkEyXkFqcGdeQXVyMTU1MDM3NDk0._V1_SX300.jpg', 'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.8/10'}, {'Source': 'Rotten Tomatoes', 'Value': '82%'}, {'Source': 'Metacritic', 'Value': '83/100'}], 'Metascore': '83', 'imdbRating': '7.8', 'imdbVotes': '1,240,509', 'imdbID': 'tt0499549', 'Type': 'movie', 'DVD': '22 Apr 2010', 'BoxOffice': '$785,221,649', 'Production': 'N/A', 'Website': 'N/A', 'Response': 'True'}
# {'Title': 'Focus', 'Year': '2015', 'Rated': 'R', 'Released': '27 Feb 2015', 'Runtime': '105 min', 'Genre': 'Comedy, Crime, Drama', 'Director': 'Glenn Ficarra, John Requa', 'Writer': 'Glenn Ficarra, John Requa', 'Actors': 'Will Smith, Margot Robbie, Rodrigo Santoro', 'Plot': "In the midst of veteran con man Nicky's latest scheme, a woman from his past - now an accomplished femme fatale - shows up and throws his plans for a loop.", 'Language': 'English, Spanish', 'Country': 'United States, Argentina', 'Awards': '3 nominations', 'Poster': 'https://m.media-amazon.com/images/M/MV5BMTUwODg2OTA4OF5BMl5BanBnXkFtZTgwOTE5MTE4MzE@._V1_SX300.jpg', 'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.6/10'}, {'Source': 'Metacritic', 'Value': '56/100'}], 'Metascore': '56', 'imdbRating': '6.6', 'imdbVotes': '248,555', 'imdbID': 'tt2381941', 'Type': 'movie', 'DVD': '23 Mar 2017', 'BoxOffice': '$53,862,963', 'Production': 'N/A', 'Website': 'N/A', 'Response': 'True'}
# {'Title': 'Inside Out', 'Year': '2015', 'Rated': 'PG', 'Released': '19 Jun 2015', 'Runtime': '95 min', 'Genre': 'Animation, Adventure, Comedy', 'Director': 'Pete Docter, Ronnie Del Carmen', 'Writer': 'Pete Docter, Ronnie Del Carmen, Meg LeFauve', 'Actors': 'Amy Poehler, Bill Hader, Lewis Black', 'Plot': 'After young Riley is uprooted from her Midwest life and moved to San Francisco, her emotions - Joy, Fear, Anger, Disgust and Sadness - conflict on how best to navigate a new city, house, and school.', 'Language': 'English, Portuguese', 'Country': 'United States', 'Awards': 'Won 1 Oscar. 101 wins & 117 nominations total', 'Poster': 'https://m.media-amazon.com/images/M/MV5BOTgxMDQwMDk0OF5BMl5BanBnXkFtZTgwNjU5OTg2NDE@._V1_SX300.jpg', 'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.2/10'}, {'Source': 'Rotten Tomatoes', 'Value': '98%'}, {'Source': 'Metacritic', 'Value': '94/100'}], 'Metascore': '94', 'imdbRating': '8.2', 'imdbVotes': '708,453', 'imdbID': 'tt2096673', 'Type': 'movie', 'DVD': '03 Nov 2015', 'BoxOffice': '$356,921,711', 'Production': 'N/A', 'Website': 'N/A', 'Response': 'True'}
# {'Title': 'Minions', 'Year': '2015', 'Rated': 'PG', 'Released': '10 Jul 2015', 'Runtime': '91 min', 'Genre': 'Animation, Adventure, Comedy', 'Director': 'Kyle Balda, Pierre Coffin', 'Writer': 'Brian Lynch', 'Actors': 'Sandra Bullock, Jon Hamm, Michael Keaton', 'Plot': 'Minions Stuart, Kevin, and Bob are recruited by Scarlet Overkill, a supervillain who, alongside her inventor husband Herb, hatches a plot to take over the world.', 'Language': 'English, Spanish', 'Country': 'United States, United Kingdom', 'Awards': 'Nominated for 1 BAFTA Award4 wins & 29 nominations total', 'Poster': 'https://m.media-amazon.com/images/M/MV5BMTg2MTMyMzU0M15BMl5BanBnXkFtZTgwOTU3ODk4NTE@._V1_SX300.jpg', 'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.4/10'}, {'Source': 'Rotten Tomatoes', 'Value': '55%'}, {'Source': 'Metacritic', 'Value': '56/100'}], 'Metascore': '56', 'imdbRating': '6.4', 'imdbVotes': '239,317', 'imdbID': 'tt2293640', 'Type': 'movie', 'DVD': '08 Dec 2015', 'BoxOffice': '$336,045,770', 'Production': 'N/A', 'Website': 'N/A', 'Response': 'True'}
# {'Title': 'Dictator', 'Year': '2016', 'Rated': 'Not Rated', 'Released': '14 Jan 2016', 'Runtime': '155 min', 'Genre': 'Action, Drama', 'Director': 'Sriwass', 'Writer': 'Kona Venkat, Gopimohan, Sriwass', 'Actors': 'Nandamuri Balakrishna, Anjali, Sonal Chauhan', 'Plot': 'Chandu lives a normal life with his in laws in Hyderabad. One fine day, he comes across an aspiring actress Sonala helps her in a critical situation. The problems gets big and Chandu lands himself in a huge mess.', 'Language': 'Telugu', 'Country': 'India', 'Awards': 'N/A', 'Poster': 'https://m.media-amazon.com/images/M/MV5BNTg3MjJjYWYtZDVmNi00MTQ1LThlNTgtMGM2ZDE3MTAwZmY0XkEyXkFqcGdeQXVyNjE1OTQ0NjA@._V1_SX300.jpg', 'Ratings': [{'Source': 'Internet Movie Database', 'Value': '4.1/10'}], 'Metascore': 'N/A', 'imdbRating': '4.1', 'imdbVotes': '697', 'imdbID': 'tt5304086', 'Type': 'movie', 'DVD': 'N/A', 'BoxOffice': '$104,734', 'Production': 'N/A', 'Website': 'N/A', 'Response': 'True'}
# {'Title': 'Deadpool', 'Year': '2016', 'Rated': 'R', 'Released': '12 Feb 2016', 'Runtime': '108 min', 'Genre': 'Action, Adventure, Comedy', 'Director': 'Tim Miller', 'Writer': 'Rhett Reese, Paul Wernick', 'Actors': 'Ryan Reynolds, Morena Baccarin, T.J. Miller', 'Plot': 'A wisecracking mercenary gets experimented on and becomes immortal but ugly, and sets out to track down the man who ruined his looks.', 'Language': 'English', 'Country': 'United States', 'Awards': '28 wins & 78 nominations', 'Poster': 'https://m.media-amazon.com/images/M/MV5BYzE5MjY1ZDgtMTkyNC00MTMyLThhMjAtZGI5OTE1NzFlZGJjXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_SX300.jpg', 'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.0/10'}, {'Source': 'Rotten Tomatoes', 'Value': '85%'}, {'Source': 'Metacritic', 'Value': '65/100'}], 'Metascore': '65', 'imdbRating': '8.0', 'imdbVotes': '1,028,602', 'imdbID': 'tt1431045', 'Type': 'movie', 'DVD': '10 May 2016', 'BoxOffice': '$363,070,709', 'Production': 'N/A', 'Website': 'N/A', 'Response': 'True'}
# {'Title': 'Arrival', 'Year': '2016', 'Rated': 'PG-13', 'Released': '11 Nov 2016', 'Runtime': '116 min', 'Genre': 'Drama, Mystery, Sci-Fi', 'Director': 'Denis Villeneuve', 'Writer': 'Eric Heisserer, Ted Chiang', 'Actors': 'Amy Adams, Jeremy Renner, Forest Whitaker', 'Plot': 'A linguist works with the military to communicate with alien lifeforms after twelve mysterious spacecraft appear around the world.', 'Language': 'English, Russian, Mandarin', 'Country': 'United States, Canada', 'Awards': 'Won 1 Oscar. 70 wins & 269 nominations total', 'Poster': 'https://m.media-amazon.com/images/M/MV5BMTExMzU0ODcxNDheQTJeQWpwZ15BbWU4MDE1OTI4MzAy._V1_SX300.jpg', 'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.9/10'}, {'Source': 'Rotten Tomatoes', 'Value': '95%'}, {'Source': 'Metacritic', 'Value': '81/100'}], 'Metascore': '81', 'imdbRating': '7.9', 'imdbVotes': '688,948', 'imdbID': 'tt2543164', 'Type': 'movie', 'DVD': '14 Feb 2017', 'BoxOffice': '$100,546,139', 'Production': 'N/A', 'Website': 'N/A', 'Response': 'True'}
# {'Title': 'The Nice Guys', 'Year': '2016', 'Rated': 'R', 'Released': '20 May 2016', 'Runtime': '116 min', 'Genre': 'Action, Comedy, Crime', 'Director': 'Shane Black', 'Writer': 'Shane Black, Anthony Bagarozzi', 'Actors': 'Russell Crowe, Ryan Gosling, Angourie Rice', 'Plot': 'In 1970s Los Angeles, a mismatched pair of private eyes investigate a missing girl and the mysterious death of a porn star.', 'Language': 'English, German', 'Country': 'United States', 'Awards': '9 wins & 34 nominations', 'Poster': 'https://m.media-amazon.com/images/M/MV5BODNlNmU4MGItMzQwZi00NGQyLWEyZWItYjFkNmI0NWI4NjBhXkEyXkFqcGdeQXVyODE5NzE3OTE@._V1_SX300.jpg', 'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.3/10'}, {'Source': 'Rotten Tomatoes', 'Value': '91%'}, {'Source': 'Metacritic', 'Value': '70/100'}], 'Metascore': '70', 'imdbRating': '7.3', 'imdbVotes': '326,352', 'imdbID': 'tt3799694', 'Type': 'movie', 'DVD': '23 Aug 2016', 'BoxOffice': '$36,261,763', 'Production': 'N/A', 'Website': 'N/A', 'Response': 'True'}

# %%
#DataFrame radi lakseg filtriranja
import pandas as pd

# %%
df = pd.DataFrame(movies)
df
# Out:
#            Title  Year      Rated     Released  Runtime  \
# 0         Avatar  2009      PG-13  18 Dec 2009  162 min
# 1          Focus  2015          R  27 Feb 2015  105 min
# 2     Inside Out  2015         PG  19 Jun 2015   95 min
# 3        Minions  2015         PG  10 Jul 2015   91 min
# 4       Dictator  2016  Not Rated  14 Jan 2016  155 min
# 5       Deadpool  2016          R  12 Feb 2016  108 min
# 6        Arrival  2016      PG-13  11 Nov 2016  116 min
# 7  The Nice Guys  2016          R  20 May 2016  116 min
#
#                           Genre                        Director  \
# 0    Action, Adventure, Fantasy                   James Cameron
# 1          Comedy, Crime, Drama       Glenn Ficarra, John Requa
# 2  Animation, Adventure, Comedy  Pete Docter, Ronnie Del Carmen
# 3  Animation, Adventure, Comedy       Kyle Balda, Pierre Coffin
# 4                 Action, Drama                         Sriwass
# 5     Action, Adventure, Comedy                      Tim Miller
# 6        Drama, Mystery, Sci-Fi                Denis Villeneuve
# 7         Action, Comedy, Crime                     Shane Black
#
#                                         Writer  \
# 0                                James Cameron
# 1                    Glenn Ficarra, John Requa
# 2  Pete Docter, Ronnie Del Carmen, Meg LeFauve
# 3                                  Brian Lynch
# 4              Kona Venkat, Gopimohan, Sriwass
# 5                    Rhett Reese, Paul Wernick
# 6                   Eric Heisserer, Ted Chiang
# 7               Shane Black, Anthony Bagarozzi
#
#                                            Actors  \
# 0  Sam Worthington, Zoe Saldana, Sigourney Weaver
# 1      Will Smith, Margot Robbie, Rodrigo Santoro
# 2            Amy Poehler, Bill Hader, Lewis Black
# 3        Sandra Bullock, Jon Hamm, Michael Keaton
# 4    Nandamuri Balakrishna, Anjali, Sonal Chauhan
# 5     Ryan Reynolds, Morena Baccarin, T.J. Miller
# 6       Amy Adams, Jeremy Renner, Forest Whitaker
# 7      Russell Crowe, Ryan Gosling, Angourie Rice
#
#                                                 Plot  ... Metascore  \
# 0  A paraplegic Marine dispatched to the moon Pan...  ...        83
# 1  In the midst of veteran con man Nicky's latest...  ...        56
# 2  After young Riley is uprooted from her Midwest...  ...        94
# 3  Minions Stuart, Kevin, and Bob are recruited b...  ...        56
# 4  Chandu lives a normal life with his in laws in...  ...       N/A
# 5  A wisecracking mercenary gets experimented on ...  ...        65
# 6  A linguist works with the military to communic...  ...        81
# 7  In 1970s Los Angeles, a mismatched pair of pri...  ...        70
#
#   imdbRating  imdbVotes     imdbID   Type          DVD     BoxOffice  \
# 0        7.8  1,240,509  tt0499549  movie  22 Apr 2010  $785,221,649
# 1        6.6    248,555  tt2381941  movie  23 Mar 2017   $53,862,963
# 2        8.2    708,453  tt2096673  movie  03 Nov 2015  $356,921,711
# 3        6.4    239,317  tt2293640  movie  08 Dec 2015  $336,045,770
# 4        4.1        697  tt5304086  movie          N/A      $104,734
# 5        8.0  1,028,602  tt1431045  movie  10 May 2016  $363,070,709
# 6        7.9    688,948  tt2543164  movie  14 Feb 2017  $100,546,139
# 7        7.3    326,352  tt3799694  movie  23 Aug 2016   $36,261,763
#
#   Production Website Response
# 0        N/A     N/A     True
# 1        N/A     N/A     True
# 2        N/A     N/A     True
# 3        N/A     N/A     True
# 4        N/A     N/A     True
# 5        N/A     N/A     True
# 6        N/A     N/A     True
# 7        N/A     N/A     True
#
# [8 rows x 25 columns]

# %%
df.dropna()
# Out:
#            Title  Year      Rated     Released  Runtime  \
# 0         Avatar  2009      PG-13  18 Dec 2009  162 min
# 1          Focus  2015          R  27 Feb 2015  105 min
# 2     Inside Out  2015         PG  19 Jun 2015   95 min
# 3        Minions  2015         PG  10 Jul 2015   91 min
# 4       Dictator  2016  Not Rated  14 Jan 2016  155 min
# 5       Deadpool  2016          R  12 Feb 2016  108 min
# 6        Arrival  2016      PG-13  11 Nov 2016  116 min
# 7  The Nice Guys  2016          R  20 May 2016  116 min
#
#                           Genre                        Director  \
# 0    Action, Adventure, Fantasy                   James Cameron
# 1          Comedy, Crime, Drama       Glenn Ficarra, John Requa
# 2  Animation, Adventure, Comedy  Pete Docter, Ronnie Del Carmen
# 3  Animation, Adventure, Comedy       Kyle Balda, Pierre Coffin
# 4                 Action, Drama                         Sriwass
# 5     Action, Adventure, Comedy                      Tim Miller
# 6        Drama, Mystery, Sci-Fi                Denis Villeneuve
# 7         Action, Comedy, Crime                     Shane Black
#
#                                         Writer  \
# 0                                James Cameron
# 1                    Glenn Ficarra, John Requa
# 2  Pete Docter, Ronnie Del Carmen, Meg LeFauve
# 3                                  Brian Lynch
# 4              Kona Venkat, Gopimohan, Sriwass
# 5                    Rhett Reese, Paul Wernick
# 6                   Eric Heisserer, Ted Chiang
# 7               Shane Black, Anthony Bagarozzi
#
#                                            Actors  \
# 0  Sam Worthington, Zoe Saldana, Sigourney Weaver
# 1      Will Smith, Margot Robbie, Rodrigo Santoro
# 2            Amy Poehler, Bill Hader, Lewis Black
# 3        Sandra Bullock, Jon Hamm, Michael Keaton
# 4    Nandamuri Balakrishna, Anjali, Sonal Chauhan
# 5     Ryan Reynolds, Morena Baccarin, T.J. Miller
# 6       Amy Adams, Jeremy Renner, Forest Whitaker
# 7      Russell Crowe, Ryan Gosling, Angourie Rice
#
#                                                 Plot  ... Metascore  \
# 0  A paraplegic Marine dispatched to the moon Pan...  ...        83
# 1  In the midst of veteran con man Nicky's latest...  ...        56
# 2  After young Riley is uprooted from her Midwest...  ...        94
# 3  Minions Stuart, Kevin, and Bob are recruited b...  ...        56
# 4  Chandu lives a normal life with his in laws in...  ...       N/A
# 5  A wisecracking mercenary gets experimented on ...  ...        65
# 6  A linguist works with the military to communic...  ...        81
# 7  In 1970s Los Angeles, a mismatched pair of pri...  ...        70
#
#   imdbRating  imdbVotes     imdbID   Type          DVD     BoxOffice  \
# 0        7.8  1,240,509  tt0499549  movie  22 Apr 2010  $785,221,649
# 1        6.6    248,555  tt2381941  movie  23 Mar 2017   $53,862,963
# 2        8.2    708,453  tt2096673  movie  03 Nov 2015  $356,921,711
# 3        6.4    239,317  tt2293640  movie  08 Dec 2015  $336,045,770
# 4        4.1        697  tt5304086  movie          N/A      $104,734
# 5        8.0  1,028,602  tt1431045  movie  10 May 2016  $363,070,709
# 6        7.9    688,948  tt2543164  movie  14 Feb 2017  $100,546,139
# 7        7.3    326,352  tt3799694  movie  23 Aug 2016   $36,261,763
#
#   Production Website Response
# 0        N/A     N/A     True
# 1        N/A     N/A     True
# 2        N/A     N/A     True
# 3        N/A     N/A     True
# 4        N/A     N/A     True
# 5        N/A     N/A     True
# 6        N/A     N/A     True
# 7        N/A     N/A     True
#
# [8 rows x 25 columns]

# %%
#Unosenje IMDB rejtinga i zanra
imdb_rating = input("Input IMDB rating")
genre = input("Input genre")
# Out:
# Input IMDB rating7
# Input genreComedy

# %%
#Izbacivanje redova kod kojih nije naveden uneti zanr
for i,genreRow in enumerate (df['Genre']):
    if genre not in genreRow:
        df.drop(i,inplace=True)

# %%
df
# Out:
#            Title  Year Rated     Released  Runtime  \
# 1          Focus  2015     R  27 Feb 2015  105 min
# 2     Inside Out  2015    PG  19 Jun 2015   95 min
# 3        Minions  2015    PG  10 Jul 2015   91 min
# 5       Deadpool  2016     R  12 Feb 2016  108 min
# 7  The Nice Guys  2016     R  20 May 2016  116 min
#
#                           Genre                        Director  \
# 1          Comedy, Crime, Drama       Glenn Ficarra, John Requa
# 2  Animation, Adventure, Comedy  Pete Docter, Ronnie Del Carmen
# 3  Animation, Adventure, Comedy       Kyle Balda, Pierre Coffin
# 5     Action, Adventure, Comedy                      Tim Miller
# 7         Action, Comedy, Crime                     Shane Black
#
#                                         Writer  \
# 1                    Glenn Ficarra, John Requa
# 2  Pete Docter, Ronnie Del Carmen, Meg LeFauve
# 3                                  Brian Lynch
# 5                    Rhett Reese, Paul Wernick
# 7               Shane Black, Anthony Bagarozzi
#
#                                         Actors  \
# 1   Will Smith, Margot Robbie, Rodrigo Santoro
# 2         Amy Poehler, Bill Hader, Lewis Black
# 3     Sandra Bullock, Jon Hamm, Michael Keaton
# 5  Ryan Reynolds, Morena Baccarin, T.J. Miller
# 7   Russell Crowe, Ryan Gosling, Angourie Rice
#
#                                                 Plot  ... Metascore  \
# 1  In the midst of veteran con man Nicky's latest...  ...        56
# 2  After young Riley is uprooted from her Midwest...  ...        94
# 3  Minions Stuart, Kevin, and Bob are recruited b...  ...        56
# 5  A wisecracking mercenary gets experimented on ...  ...        65
# 7  In 1970s Los Angeles, a mismatched pair of pri...  ...        70
#
#   imdbRating  imdbVotes     imdbID   Type          DVD     BoxOffice  \
# 1        6.6    248,555  tt2381941  movie  23 Mar 2017   $53,862,963
# 2        8.2    708,453  tt2096673  movie  03 Nov 2015  $356,921,711
# 3        6.4    239,317  tt2293640  movie  08 Dec 2015  $336,045,770
# 5        8.0  1,028,602  tt1431045  movie  10 May 2016  $363,070,709
# 7        7.3    326,352  tt3799694  movie  23 Aug 2016   $36,261,763
#
#   Production Website Response
# 1        N/A     N/A     True
# 2        N/A     N/A     True
# 3        N/A     N/A     True
# 5        N/A     N/A     True
# 7        N/A     N/A     True
#
# [5 rows x 25 columns]

# %%
#Promena tipa kolone imdbRating iz object u float radi filtriranja po vrednosti vecoj ili jednakoj od unete
df['imdbRating']=pd.to_numeric(df['imdbRating'])

# %%
df.dtypes
# Out:
# Title          object
# Year           object
# Rated          object
# Released       object
# Runtime        object
# Genre          object
# Director       object
# Writer         object
# Actors         object
# Plot           object
# Language       object
# Country        object
# Awards         object
# Poster         object
# Ratings        object
# Metascore      object
# imdbRating    float64
# imdbVotes      object
# imdbID         object
# Type           object
# DVD            object
# BoxOffice      object
# Production     object
# Website        object
# Response       object
# dtype: object

# %%
#Filtriranje po koloni imdbRating 
df_filtered = df[df['imdbRating'] >= pd.to_numeric(imdb_rating)]

# %%
df_filtered
# Out:
#            Title  Year Rated     Released  Runtime  \
# 2     Inside Out  2015    PG  19 Jun 2015   95 min
# 5       Deadpool  2016     R  12 Feb 2016  108 min
# 7  The Nice Guys  2016     R  20 May 2016  116 min
#
#                           Genre                        Director  \
# 2  Animation, Adventure, Comedy  Pete Docter, Ronnie Del Carmen
# 5     Action, Adventure, Comedy                      Tim Miller
# 7         Action, Comedy, Crime                     Shane Black
#
#                                         Writer  \
# 2  Pete Docter, Ronnie Del Carmen, Meg LeFauve
# 5                    Rhett Reese, Paul Wernick
# 7               Shane Black, Anthony Bagarozzi
#
#                                         Actors  \
# 2         Amy Poehler, Bill Hader, Lewis Black
# 5  Ryan Reynolds, Morena Baccarin, T.J. Miller
# 7   Russell Crowe, Ryan Gosling, Angourie Rice
#
#                                                 Plot  ... Metascore  \
# 2  After young Riley is uprooted from her Midwest...  ...        94
# 5  A wisecracking mercenary gets experimented on ...  ...        65
# 7  In 1970s Los Angeles, a mismatched pair of pri...  ...        70
#
#   imdbRating  imdbVotes     imdbID   Type          DVD     BoxOffice  \
# 2        8.2    708,453  tt2096673  movie  03 Nov 2015  $356,921,711
# 5        8.0  1,028,602  tt1431045  movie  10 May 2016  $363,070,709
# 7        7.3    326,352  tt3799694  movie  23 Aug 2016   $36,261,763
#
#   Production Website Response
# 2        N/A     N/A     True
# 5        N/A     N/A     True
# 7        N/A     N/A     True
#
# [3 rows x 25 columns]

# %%
#Ispisivanje rezultata u datoteku out.txt
df_filtered.to_csv('out.txt', header=False, index = False)
